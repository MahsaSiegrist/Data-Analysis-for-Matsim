# %%
# library
import pandas as pd
import numpy as np
#import googlemaps
from geopy.geocoders import Nominatim

# %%
# the name of the app (no need to change)
geolocator = Nominatim(user_agent="defultName")

# %% [markdown]
# # STEP 1 read the files

# %%
df1 = pd.read_csv("replan_current_information.txt",sep="\t", error_bad_lines=False, index_col =None)
df2 = pd.read_csv("replan_replan_when_boardingDenied.txt",sep="\t", error_bad_lines=False, index_col =None)

# %%
# read the replan.nodisruption.txt (Read the second databae)
#df2 = pd.read_csv("replan_replan_when_boardingDenied.txt",sep="\t", error_bad_lines=False, index_col =None)
len(df2)
df2.head()
# Out:
#    iteration    personId     time OutTime triggerType  \
# 0          0  1394529300  57600.0  16:0:0         T-2
# 1          0  1152035700  57600.0  16:0:0         T-2
# 2          0  1016616800  57600.0  16:0:0         T-2
# 3          0  1613689101  57600.0  16:0:0         T-2
# 4          0   919327800  57606.0  16:0:6         T-2
#
#                   currentStopName  transitLine transitRoute         vehicle  \
# 0          Zürich, Einfangstrasse   VBZ_line62    15661_080  NFB_VBZ_140751
# 1               Zürich, Klusplatz  VBZ_line703    23724_001  NFB_VBZ_142004
# 2  Mellingen Heitersberg, Bahnhof  PAG_line362    36202_038   BUS_PAG_95481
# 3            Zürich, Lerchenhalde   VBZ_line80    06342_167  NFB_VBZ_138485
# 4               Zürich, Klusplatz   VBZ_line33    00881_001  NFB_VBZ_137778
#
#                      nextStopName  passengersSize  passengerCapacit
# 0        Zürich, Zehntenhausplatz               1                 1
# 1  Zürich, Carl-Spitteler-Strasse               1                 1
# 2           Mellingen, Meierhofer               1                 1
# 3           Zürich, Schumacherweg               1                 1
# 4          Zürich, Hölderlinsteig               1                 1

# %%
print(df1.shape)
print(df2.shape)
# Out:
# (1880, 12)
# (1496, 12)

# %% [markdown]
# # STEP 2 just keep T2 in file one

# %%
df1 = df1[df1["triggerType"]=="T-2"]

# %%
print(df1.shape)
# Out:
# (1749, 12)

# %%
len(df1.personId.unique())
# Out:
# 625

# %%
len(df2.personId.unique())
# Out:
# 554

# %% [markdown]
# # STEP 3 Remove duplicates in each file

# %%
df1 = df1.drop_duplicates(subset=['personId', 'triggerType',
       'currentStopName', 'transitLine', 'transitRoute', 'vehicle',
       'nextStopName', 'passengersSize', 'passengerCapacit'] , keep='first')
df1.shape
# Out:
# (1006, 12)

# %%
len(df1.personId.unique())
# Out:
# 625

# %%
df2 = df2.drop_duplicates(subset=['personId', 'triggerType',
       'currentStopName', 'transitLine', 'transitRoute', 'vehicle',
       'nextStopName', 'passengersSize', 'passengerCapacit'] , keep='first')
df2.shape
# Out:
# (842, 12)

# %%
len(df2.personId.unique())
# Out:
# 554

# %% [markdown]
# # Step 4 Compare the two files
# 1. All values are the same in all columns

# %%
# merged the two database with indicators demoestrating which row belongs to which database
df3 = pd.merge(df1,df2, how='outer', indicator=True)
len(df3)
df3.head()
# Out:
#    iteration    personId     time OutTime triggerType  \
# 0          0  1016616800  57600.0  16:0:0         T-2
# 1          0  1152035700  57600.0  16:0:0         T-2
# 2          0  1613689101  57600.0  16:0:0         T-2
# 3          0  1394529300  57600.0  16:0:0         T-2
# 4          0   919327800  57606.0  16:0:6         T-2
#
#                   currentStopName  transitLine transitRoute         vehicle  \
# 0  Mellingen Heitersberg, Bahnhof  PAG_line362    36202_038   BUS_PAG_95481
# 1               Zürich, Klusplatz  VBZ_line703    23724_001  NFB_VBZ_142004
# 2            Zürich, Lerchenhalde   VBZ_line80    06342_167  NFB_VBZ_138485
# 3          Zürich, Einfangstrasse   VBZ_line62    15661_080  NFB_VBZ_140751
# 4               Zürich, Klusplatz   VBZ_line33    00881_001  NFB_VBZ_137778
#
#                      nextStopName  passengersSize  passengerCapacit _merge
# 0           Mellingen, Meierhofer               1                 1   both
# 1  Zürich, Carl-Spitteler-Strasse               1                 1   both
# 2           Zürich, Schumacherweg               1                 1   both
# 3        Zürich, Zehntenhausplatz               1                 1   both
# 4          Zürich, Hölderlinsteig               1                 1   both

# %%
len(df3)
# Out:
# 1058

# %%
len(df3.personId.unique())
# Out:
# 648

# %% [markdown]
# # ALL the Same

# %%
# Merge all the values between the two data frames that are exactly the same (with inner)
df_all_same = pd.merge(df1, df2 , on= ['iteration', 'personId', 'time', 'OutTime', 'triggerType',
       'currentStopName', 'transitLine', 'transitRoute', 'vehicle',
       'nextStopName', 'passengersSize', 'passengerCapacit'])

# %%
len(df_all_same)
# Out:
# 790

# %%
len(df_all_same.personId.unique())
# Out:
# 525

# %%
df_all_same
# Out:
#      iteration    personId     time   OutTime triggerType  \
# 0            0  1016616800  57600.0    16:0:0         T-2
# 1            0  1152035700  57600.0    16:0:0         T-2
# 2            0  1613689101  57600.0    16:0:0         T-2
# 3            0  1394529300  57600.0    16:0:0         T-2
# 4            0   919327800  57606.0    16:0:6         T-2
# ..         ...         ...      ...       ...         ...
# 785          0  1216331700  80230.0  22:17:10         T-2
# 786          0  1137212800  80350.0  22:19:10         T-2
# 787          0  1102120800  80400.0   22:20:0         T-2
# 788          0  1041649401  81003.0   22:30:3         T-2
# 789          0  1454600901  81068.0   22:31:8         T-2
#
#                     currentStopName  transitLine transitRoute         vehicle  \
# 0    Mellingen Heitersberg, Bahnhof  PAG_line362    36202_038   BUS_PAG_95481
# 1                 Zürich, Klusplatz  VBZ_line703    23724_001  NFB_VBZ_142004
# 2              Zürich, Lerchenhalde   VBZ_line80    06342_167  NFB_VBZ_138485
# 3            Zürich, Einfangstrasse   VBZ_line62    15661_080  NFB_VBZ_140751
# 4                 Zürich, Klusplatz   VBZ_line33    00881_001  NFB_VBZ_137778
# ..                              ...          ...          ...             ...
# 785           Winterthur, Technikum    SBW_line3    00238_002  NFB_SBW_151756
# 786      Zürich Hardbrücke, Bahnhof   VBZ_line72    04444_001  NFB_VBZ_137919
# 787                Zürich, Hubertus   VBZ_line33    00881_001  NFB_VBZ_137047
# 788           Oberglatt ZH, Bahnhof  PAG_line525    52502_033   NFB_PAG_98083
# 789      Hagendorn, Ziegelei-Museum   ZVB_line43    00305_002  NFB_ZVB_131971
#
#                        nextStopName  passengersSize  passengerCapacit
# 0             Mellingen, Meierhofer               1                 1
# 1    Zürich, Carl-Spitteler-Strasse               1                 1
# 2             Zürich, Schumacherweg               1                 1
# 3          Zürich, Zehntenhausplatz               1                 1
# 4            Zürich, Hölderlinsteig               1                 1
# ..                              ...             ...               ...
# 785       Winterthur, Gewerbeschule               1                 1
# 786               Zürich, Hardplatz               1                 1
# 787                Zürich, Sackzelg               1                 1
# 788  Oberglatt ZH, Mösli Hofstetten               1                 1
# 789           Hagendorn, Grobenmoos               1                 1
#
# [790 rows x 12 columns]

# %%
df_all_same.to_excel("allTheSame.xlsx")

# %%
# Merge all the values between the two data frames that are exactly the same (with inner)
df_all_same_personId = pd.merge(df1, df2 , on= ['personId'])

# %%
len(df_all_same_personId)
# Out:
# 1723

# %%
len(df_all_same_personId.personId.unique())
# Out:
# 531

# %% [markdown]
# # Just in the Current file

# %%
# Filter the merged databse into two database, indirecedEffect and Tocheck databases.
df_indirectEffect = df3[df3["_merge"]=="left_only"]
df_indirectEffect.to_excel("indirectEffect.xlsx")
df_indirectEffect.head()
# Out:
#     iteration    personId     time   OutTime triggerType  \
# 15          0  1557445300  57852.0   16:4:12         T-2
# 16          0  1192519601  57900.0    16:5:0         T-2
# 17          0   914693600  57906.0    16:5:6         T-2
# 44          0  1488941500  58440.0   16:14:0         T-2
# 54          0  1248398200  58667.0  16:17:47         T-2
#
#               currentStopName              transitLine transitRoute  \
# 15            Zürich Oerlikon   SBB_S6_8503105-8503504    18622_003
# 16     Zürich, Bahnhofquai/HB               VBZ_line46    07822_178
# 17  Zürich, Stampfenbachplatz               VBZ_line46    07822_178
# 44       Zürich, Rebbergsteig               VBZ_line46    07822_178
# 54            Zürich Oerlikon  SBB_S24_8502204-8506000    20420_001
#
#            vehicle               nextStopName  passengersSize  \
# 15     S_SBB_04321             Zürich Seebach               0
# 16  NFB_VBZ_139413  Zürich, Stampfenbachplatz               1
# 17  NFB_VBZ_139413        Zürich, Nordstrasse               1
# 44  NFB_VBZ_139413      Zürich, Kempfhofsteig               1
# 54     S_SBB_05050           Zürich Flughafen               0
#
#     passengerCapacit     _merge
# 15                30  left_only
# 16                 1  left_only
# 17                 1  left_only
# 44                 1  left_only
# 54                30  left_only

# %%
len(df_indirectEffect)
# Out:
# 216

# %%
len(df_indirectEffect.personId.unique())
# Out:
# 130

# %% [markdown]
# # Just in the repaln file

# %%
# Filter the merged databse into two database, indirecedEffect and Tocheck databases.
df_to_check = df3[df3["_merge"]=="right_only"]
df_to_check.to_excel("to_check.xlsx")
df_to_check.head()
# Out:
#       iteration    personId     time   OutTime triggerType  \
# 1006          0  1491268300  59894.0  16:38:14         T-2
# 1007          0  1374678600  60180.0   16:43:0         T-2
# 1008          0  1374678600  60492.0  16:48:12         T-2
# 1009          0   866277600  60840.0   16:54:0         T-2
# 1010          0  1374678600  60972.0  16:56:12         T-2
#
#                 currentStopName  transitLine transitRoute         vehicle  \
# 1006     Schwerzenbach ZH, Dorf  VBZ_line704    30235_067  NFB_VBZ_142999
# 1007   Zürich, Albisriederplatz   VBZ_line72    04444_001  NFB_VBZ_138727
# 1008   Zürich, Albisriederplatz   VBZ_line72    04444_001  NFB_VBZ_138726
# 1009  Zürich, Escher-Wyss-Platz   VBZ_line33    06358_153  NFB_VBZ_140790
# 1010   Zürich, Albisriederplatz   VBZ_line72    04444_001  NFB_VBZ_138725
#
#                     nextStopName  passengersSize  passengerCapacit      _merge
# 1006        Fällanden, Industrie               1                 1  right_only
# 1007   Zürich, Friedhof Sihlfeld               1                 1  right_only
# 1008   Zürich, Friedhof Sihlfeld               1                 1  right_only
# 1009  Zürich, Rosengartenstrasse               1                 1  right_only
# 1010   Zürich, Friedhof Sihlfeld               1                 1  right_only

# %%
len(df_to_check)
# Out:
# 52

# %%
len(df_to_check.personId.unique())
# Out:
# 38

# %% [markdown]
# # Agents in the current

# %%
df=pd.merge(df1,df2,on='personId',how="outer",indicator=True)
result1 = df[df['_merge'] =='left_only']
result1u = result1.drop_duplicates(subset=['personId'])
result1u
# Out:
#       iteration_x    personId   time_x OutTime_x triggerType_x  \
# 29            0.0  1557445300  57852.0   16:4:12           T-2
# 30            0.0  1192519601  57900.0    16:5:0           T-2
# 31            0.0   914693600  57906.0    16:5:6           T-2
# 87            0.0  1488941500  58440.0   16:14:0           T-2
# 115           0.0  1248398200  58667.0  16:17:47           T-2
# ...           ...         ...      ...       ...           ...
# 1764          0.0  1576900000  70200.0   19:30:0           T-2
# 1796          0.0  1167897300  70980.0   19:43:0           T-2
# 1797          0.0  1013842400  71171.0  19:46:11           T-2
# 1818          0.0   807239400  71468.0   19:51:8           T-2
# 1884          0.0  1226850700  82980.0    23:3:0           T-2
#
#                   currentStopName_x            transitLine_x transitRoute_x  \
# 29                  Zürich Oerlikon   SBB_S6_8503105-8503504      18622_003
# 30           Zürich, Bahnhofquai/HB               VBZ_line46      07822_178
# 31        Zürich, Stampfenbachplatz               VBZ_line46      07822_178
# 87             Zürich, Rebbergsteig               VBZ_line46      07822_178
# 115                 Zürich Oerlikon  SBB_S24_8502204-8506000      20420_001
# ...                             ...                      ...            ...
# 1764           Bassersdorf, Bahnhof              VBG_line765      09927_066
# 1796           Wallisellen, Bahnhof              VBG_line759      03789_076
# 1797                Zürich, Altried              VBG_line759      03789_076
# 1818      Niederglatt ZH, Nöschikon              PAG_line510      51007_004
# 1884  Zürich, Schaufelbergerstrasse               VBZ_line89      12965_008
#
#            vehicle_x                  nextStopName_x  ...  OutTime_y  \
# 29       S_SBB_04321                  Zürich Seebach  ...        NaN
# 30    NFB_VBZ_139413       Zürich, Stampfenbachplatz  ...        NaN
# 31    NFB_VBZ_139413             Zürich, Nordstrasse  ...        NaN
# 87    NFB_VBZ_139413           Zürich, Kempfhofsteig  ...        NaN
# 115      S_SBB_05050                Zürich Flughafen  ...        NaN
# ...              ...                             ...  ...        ...
# 1764   NFB_VBG_71442    Bassersdorf, Dietlikonerstr.  ...        NaN
# 1796   NFB_VBG_69520       Wallisellen, Florastrasse  ...        NaN
# 1797   NFB_VBG_69520  Dübendorf, Sport Heerenschürli  ...        NaN
# 1818   NFB_PAG_96867     Riedt b. Neerach, Riedacher  ...        NaN
# 1884  NFB_VBZ_140439                  Zürich, Im Gut  ...        NaN
#
#       triggerType_y  currentStopName_y  transitLine_y transitRoute_y  \
# 29              NaN                NaN            NaN            NaN
# 30              NaN                NaN            NaN            NaN
# 31              NaN                NaN            NaN            NaN
# 87              NaN                NaN            NaN            NaN
# 115             NaN                NaN            NaN            NaN
# ...             ...                ...            ...            ...
# 1764            NaN                NaN            NaN            NaN
# 1796            NaN                NaN            NaN            NaN
# 1797            NaN                NaN            NaN            NaN
# 1818            NaN                NaN            NaN            NaN
# 1884            NaN                NaN            NaN            NaN
#
#      vehicle_y nextStopName_y passengersSize_y passengerCapacit_y     _merge
# 29         NaN            NaN              NaN                NaN  left_only
# 30         NaN            NaN              NaN                NaN  left_only
# 31         NaN            NaN              NaN                NaN  left_only
# 87         NaN            NaN              NaN                NaN  left_only
# 115        NaN            NaN              NaN                NaN  left_only
# ...        ...            ...              ...                ...        ...
# 1764       NaN            NaN              NaN                NaN  left_only
# 1796       NaN            NaN              NaN                NaN  left_only
# 1797       NaN            NaN              NaN                NaN  left_only
# 1818       NaN            NaN              NaN                NaN  left_only
# 1884       NaN            NaN              NaN                NaN  left_only
#
# [94 rows x 24 columns]

# %%
len(df_to_check)
# Out:
# 52

# %%
len(df_to_check.personId.unique())
# Out:
# 38

# %% [markdown]
# # Just in the replan file

# %%
df=pd.merge(df2,df1,on='personId',how="outer",indicator=True)
result2 = df[df['_merge']=='left_only']
result2u = result2.drop_duplicates(subset=['personId'])
result2u
# Out:
#       iteration_x    personId   time_x OutTime_x triggerType_x  \
# 241           0.0  1374678600  60180.0   16:43:0           T-2
# 318           0.0   866277600  60840.0   16:54:0           T-2
# 528           0.0  1259112400  61680.0    17:8:0           T-2
# 611           0.0  1039077800  61999.0  17:13:19           T-2
# 737           0.0  1305429200  62647.0   17:24:7           T-2
# 738           0.0  1438122300  62647.0   17:24:7           T-2
# 781           0.0   948954700  62830.0  17:27:10           T-2
# 832           0.0  1112900700  63060.0   17:31:0           T-2
# 894           0.0  1474441500  63370.0  17:36:10           T-2
# 941           0.0  1225850100  63730.0  17:42:10           T-2
# 1008          0.0  1318501500  64323.0   17:52:3           T-2
# 1016          0.0  1138634100  64450.0  17:54:10           T-2
# 1019          0.0  1468827800  64511.0  17:55:11           T-2
# 1068          0.0  1064200700  64803.0    18:0:3           T-2
# 1098          0.0  1356225300  64860.0    18:1:0           T-2
# 1336          0.0  1226940500  66134.0  18:22:14           T-2
# 1344          0.0  1323639800  66250.0  18:24:10           T-2
# 1345          0.0   849754800  66250.0  18:24:10           T-2
# 1359          0.0  1270474500  66314.0  18:25:14           T-2
# 1418          0.0  1612395300  66600.0   18:30:0           T-2
# 1455          0.0  1543316200  66789.0   18:33:9           T-2
# 1605          0.0   875170800  69071.0  19:11:11           T-2
# 1709          0.0   875430900  73150.0  20:19:10           T-2
#
#                currentStopName_x transitLine_x transitRoute_x       vehicle_x  \
# 241     Zürich, Albisriederplatz    VBZ_line72      04444_001  NFB_VBZ_138727
# 318    Zürich, Escher-Wyss-Platz    VBZ_line33      06358_153  NFB_VBZ_140790
# 528    Zürich, Schaffhauserplatz    VBZ_line33      06358_153  NFB_VBZ_140785
# 611     Zürich Flughafen, Fracht   VBG_line765      09927_066   NFB_VBG_71620
# 737   Zürich Hardbrücke, Bahnhof    VBZ_line72      04444_001  NFB_VBZ_138717
# 738   Zürich Hardbrücke, Bahnhof    VBZ_line72      04444_001  NFB_VBZ_138717
# 781   Zürich Hardbrücke, Bahnhof    VBZ_line33      00881_001  NFB_VBZ_137754
# 832        Oberglatt ZH, Bahnhof   PAG_line504      50402_001   NFB_PAG_96764
# 894   Zürich Hardbrücke, Bahnhof    VBZ_line83      37782_046  NFB_VBZ_143893
# 941   Zürich Hardbrücke, Bahnhof    VBZ_line33      00881_001  NFB_VBZ_137752
# 1008         Glattbrugg, Bahnhof   VBG_line762      06632_043   NFB_VBG_70323
# 1016  Zürich Hardbrücke, Bahnhof    VBZ_line72      04444_001  NFB_VBZ_138709
# 1019        Bassersdorf, Bahnhof   VBG_line765      09927_066   NFB_VBG_71575
# 1068       Oberglatt ZH, Bahnhof   PAG_line504      50402_001   NFB_PAG_96766
# 1098         Regensdorf, Zentrum   VBG_line485      03952_089   NFB_VBG_69625
# 1336    Zürich Oerlikon, Bahnhof    VBZ_line61      07884_001  NFB_VBZ_138908
# 1344  Zürich Hardbrücke, Bahnhof    VBZ_line72      04444_001  NFB_VBZ_138703
# 1345  Zürich Hardbrücke, Bahnhof    VBZ_line72      04444_001  NFB_VBZ_138703
# 1359        Bassersdorf, Bahnhof   VBG_line765      09927_066   NFB_VBG_71529
# 1418    Winterthur, Hauptbahnhof     SBW_line2      00154_001  NFB_SBW_151692
# 1455            Zürich, Sackzelg    VBZ_line67      13716_105  NFB_VBZ_141039
# 1605     Zürich, Glaubtenstrasse    VBZ_line62      07921_002  NFB_VBZ_138907
# 1709  Zürich Hardbrücke, Bahnhof    VBZ_line72      04444_001  NFB_VBZ_137939
#
#                     nextStopName_x  ...  OutTime_y  triggerType_y  \
# 241      Zürich, Friedhof Sihlfeld  ...        NaN            NaN
# 318     Zürich, Rosengartenstrasse  ...        NaN            NaN
# 528      Zürich, Scheuchzerstrasse  ...        NaN            NaN
# 611        Kloten, Zum Wilden Mann  ...        NaN            NaN
# 737              Zürich, Hardplatz  ...        NaN            NaN
# 738              Zürich, Hardplatz  ...        NaN            NaN
# 781              Zürich, Hardplatz  ...        NaN            NaN
# 832           Oberglatt ZH, Rietli  ...        NaN            NaN
# 894              Zürich, Hardplatz  ...        NaN            NaN
# 941              Zürich, Hardplatz  ...        NaN            NaN
# 1008           Glattbrugg, Zentrum  ...        NaN            NaN
# 1016             Zürich, Hardplatz  ...        NaN            NaN
# 1019  Bassersdorf, Dietlikonerstr.  ...        NaN            NaN
# 1068          Oberglatt ZH, Rietli  ...        NaN            NaN
# 1098           Regensdorf, Ostring  ...        NaN            NaN
# 1336      Zürich, Sternen Oerlikon  ...        NaN            NaN
# 1344             Zürich, Hardplatz  ...        NaN            NaN
# 1345             Zürich, Hardplatz  ...        NaN            NaN
# 1359  Bassersdorf, Dietlikonerstr.  ...        NaN            NaN
# 1418         Winterthur, Technikum  ...        NaN            NaN
# 1455     Zürich, Fellenbergstrasse  ...        NaN            NaN
# 1605          Zürich, Neuaffoltern  ...        NaN            NaN
# 1709             Zürich, Hardplatz  ...        NaN            NaN
#
#       currentStopName_y  transitLine_y transitRoute_y vehicle_y  \
# 241                 NaN            NaN            NaN       NaN
# 318                 NaN            NaN            NaN       NaN
# 528                 NaN            NaN            NaN       NaN
# 611                 NaN            NaN            NaN       NaN
# 737                 NaN            NaN            NaN       NaN
# 738                 NaN            NaN            NaN       NaN
# 781                 NaN            NaN            NaN       NaN
# 832                 NaN            NaN            NaN       NaN
# 894                 NaN            NaN            NaN       NaN
# 941                 NaN            NaN            NaN       NaN
# 1008                NaN            NaN            NaN       NaN
# 1016                NaN            NaN            NaN       NaN
# 1019                NaN            NaN            NaN       NaN
# 1068                NaN            NaN            NaN       NaN
# 1098                NaN            NaN            NaN       NaN
# 1336                NaN            NaN            NaN       NaN
# 1344                NaN            NaN            NaN       NaN
# 1345                NaN            NaN            NaN       NaN
# 1359                NaN            NaN            NaN       NaN
# 1418                NaN            NaN            NaN       NaN
# 1455                NaN            NaN            NaN       NaN
# 1605                NaN            NaN            NaN       NaN
# 1709                NaN            NaN            NaN       NaN
#
#      nextStopName_y passengersSize_y passengerCapacit_y     _merge
# 241             NaN              NaN                NaN  left_only
# 318             NaN              NaN                NaN  left_only
# 528             NaN              NaN                NaN  left_only
# 611             NaN              NaN                NaN  left_only
# 737             NaN              NaN                NaN  left_only
# 738             NaN              NaN                NaN  left_only
# 781             NaN              NaN                NaN  left_only
# 832             NaN              NaN                NaN  left_only
# 894             NaN              NaN                NaN  left_only
# 941             NaN              NaN                NaN  left_only
# 1008            NaN              NaN                NaN  left_only
# 1016            NaN              NaN                NaN  left_only
# 1019            NaN              NaN                NaN  left_only
# 1068            NaN              NaN                NaN  left_only
# 1098            NaN              NaN                NaN  left_only
# 1336            NaN              NaN                NaN  left_only
# 1344            NaN              NaN                NaN  left_only
# 1345            NaN              NaN                NaN  left_only
# 1359            NaN              NaN                NaN  left_only
# 1418            NaN              NaN                NaN  left_only
# 1455            NaN              NaN                NaN  left_only
# 1605            NaN              NaN                NaN  left_only
# 1709            NaN              NaN                NaN  left_only
#
# [23 rows x 24 columns]

# %%
len(df_to_check)
# Out:
# 52

# %%
len(df_to_check.personId.unique())
# Out:
# 38

# %% [markdown]
# # Step 5

# %%
df_indirectEffect_no_duplication = df_indirectEffect.drop_duplicates(keep="first").reset_index(drop=True)
print ("the length of the city_df is {}".format(len(df_indirectEffect_no_duplication)))
df_indirectEffect_no_duplication.head()
# Out:
# the length of the city_df is 216
#    iteration    personId     time   OutTime triggerType  \
# 0          0  1557445300  57852.0   16:4:12         T-2
# 1          0  1192519601  57900.0    16:5:0         T-2
# 2          0   914693600  57906.0    16:5:6         T-2
# 3          0  1488941500  58440.0   16:14:0         T-2
# 4          0  1248398200  58667.0  16:17:47         T-2
#
#              currentStopName              transitLine transitRoute  \
# 0            Zürich Oerlikon   SBB_S6_8503105-8503504    18622_003
# 1     Zürich, Bahnhofquai/HB               VBZ_line46    07822_178
# 2  Zürich, Stampfenbachplatz               VBZ_line46    07822_178
# 3       Zürich, Rebbergsteig               VBZ_line46    07822_178
# 4            Zürich Oerlikon  SBB_S24_8502204-8506000    20420_001
#
#           vehicle               nextStopName  passengersSize  \
# 0     S_SBB_04321             Zürich Seebach               0
# 1  NFB_VBZ_139413  Zürich, Stampfenbachplatz               1
# 2  NFB_VBZ_139413        Zürich, Nordstrasse               1
# 3  NFB_VBZ_139413      Zürich, Kempfhofsteig               1
# 4     S_SBB_05050           Zürich Flughafen               0
#
#    passengerCapacit     _merge
# 0                30  left_only
# 1                 1  left_only
# 2                 1  left_only
# 3                 1  left_only
# 4                30  left_only

# %%
# find the indivisual "currentStopName" and remove the repitition
city_list = list(set(df_indirectEffect_no_duplication["currentStopName"].to_list()))
city_df = pd.DataFrame(city_list, columns =['currentStopName'])
print ("the length of the city_df is {}".format(len(city_df)))
city_df.head()
# Out:
# the length of the city_df is 66
#                currentStopName
# 0             Zürich, Im Ebnet
# 1   Adlikon b. R., Pächterried
# 2          Lufingen, Unterdorf
# 3  Glattbrugg, Frohbühlstrasse
# 4         Bassersdorf, Bahnhof

# %%
# %%time
# expand the city_df dataframe by finding the coordination of each "currentStopName"
city_df["latitude"] = None
city_df["longitude"] = None

for idx in range(len(city_df)):
    try:
        address = city_df["currentStopName"][idx] 
        location = geolocator.geocode(address, addressdetails=True)
        city_df.at[idx, "latitude"] = location.raw["lat"]
        city_df.at[idx, "longitude"] = location.raw["lon"]
    except:
        address = city_df["currentStopName"][idx].split(", ")[0] + ", switzerland"
        try:
            location = geolocator.geocode(address, addressdetails=True)
            city_df.at[idx, "latitude"] = location.raw["lat"]
            city_df.at[idx, "longitude"] = location.raw["lon"]
        except:
            address = city_df["currentStopName"][idx].split(", ")[0] + ", ch"
            try:
                location = geolocator.geocode(address, addressdetails=True)
                city_df.at[idx, "latitude"] = location.raw["lat"]
                city_df.at[idx, "longitude"] = location.raw["lon"]
            except:
                pass         
    finally:
        print ("% " + str(idx/len(city_df) * 100))
print ("the length of the city_df is {}".format(len(city_df)))
city_df.head()
# Out:
# % 0.0
# % 1.5151515151515151
# % 3.0303030303030303
# % 4.545454545454546
# % 6.0606060606060606
# % 7.575757575757576
# % 9.090909090909092
# % 10.606060606060606
# % 12.121212121212121
# % 13.636363636363635
# % 15.151515151515152
# % 16.666666666666664
# % 18.181818181818183
# % 19.696969696969695
# % 21.21212121212121
# % 22.727272727272727
# % 24.242424242424242
# % 25.757575757575758
# % 27.27272727272727
# % 28.78787878787879
# % 30.303030303030305
# % 31.818181818181817
# % 33.33333333333333
# % 34.84848484848485
# % 36.36363636363637
# % 37.878787878787875
# % 39.39393939393939
# % 40.909090909090914
# % 42.42424242424242
# % 43.93939393939394
# % 45.45454545454545
# % 46.96969696969697
# % 48.484848484848484
# % 50.0
# % 51.515151515151516
# % 53.03030303030303
# % 54.54545454545454
# % 56.060606060606055
# % 57.57575757575758
# % 59.09090909090909
# % 60.60606060606061
# % 62.121212121212125
# % 63.63636363636363
# % 65.15151515151516
# % 66.66666666666666
# % 68.18181818181817
# % 69.6969696969697
# % 71.21212121212122
# % 72.72727272727273
# % 74.24242424242425
# % 75.75757575757575
# % 77.27272727272727
# % 78.78787878787878
# % 80.3030303030303
# % 81.81818181818183
# % 83.33333333333334
# % 84.84848484848484
# % 86.36363636363636
# % 87.87878787878788
# % 89.39393939393939
# % 90.9090909090909
# % 92.42424242424242
# % 93.93939393939394
# % 95.45454545454545
# % 96.96969696969697
# % 98.48484848484848
# the length of the city_df is 66
# Wall time: 2min 21s
#                currentStopName    latitude  longitude
# 0             Zürich, Im Ebnet  47.2878684  8.5576186
# 1   Adlikon b. R., Pächterried        None       None
# 2          Lufingen, Unterdorf        None       None
# 3  Glattbrugg, Frohbühlstrasse        None       None
# 4         Bassersdorf, Bahnhof        None       None

# %%
# change the data type of "latitude" and "longitude" columns from string to float
city_df["latitude"] = city_df["latitude"].astype(float)
city_df["longitude"] = city_df["longitude"].astype(float)

# %%
# Show the rows where "latitude" and "longitude" could not be found.  
city_df[city_df["latitude"].isnull()].head()
# Out:
#                currentStopName  latitude  longitude
# 1   Adlikon b. R., Pächterried       NaN        NaN
# 2          Lufingen, Unterdorf       NaN        NaN
# 3  Glattbrugg, Frohbühlstrasse       NaN        NaN
# 4         Bassersdorf, Bahnhof       NaN        NaN
# 6         Wetzikon ZH, Bahnhof       NaN        NaN

# %%
# Switzerland boundaries
lat_min = 45.827413
lat_max = 47.775553
lon_min = 5.952471
lon_max = 10.467563

# %%
# list of the stations found out of the country
out_of_country = city_df[(city_df["latitude"]>=lat_max) | (city_df["latitude"]<=lat_min) | \
                            (city_df["longitude"]>=lon_max)| (city_df["longitude"]<=lon_min)]
# take out the index
out_of_country_index = out_of_country.index.to_list()
print ("list of indices need to be corrected:" , out_of_country_index)
out_of_country.head()
# Out:
# list of indices need to be corrected: []
# Empty DataFrame
# Columns: [currentStopName, latitude, longitude]
# Index: []

# %%
# here we apply the loop once again over the places where found out of the country of Switzerland 
for idx in out_of_country_index:
    city_df.loc[idx, "latitude"] = np.nan
    city_df.loc[idx, "longitude"] = np.nan
    try:
        new_address = ", ".join(city_df.loc[idx, "currentStopName"].split(", ")[::-1]) + ", swiss" 
        location = geolocator.geocode(new_address, addressdetails=True)
        city_df.at[idx, "latitude"] = location.raw["lat"]
        city_df.at[idx, "longitude"] = location.raw["lon"]
    except:
        pass

# %%
# change the data type of "latitude" and "longitude" columns from string to float
city_df["latitude"] = city_df["latitude"].astype(float)
city_df["longitude"] = city_df["longitude"].astype(float)

# %%
# Let's see if there are still a place not found by the code
city_df[city_df["latitude"].isnull()].head()
# Out:
#                currentStopName  latitude  longitude
# 1   Adlikon b. R., Pächterried       NaN        NaN
# 2          Lufingen, Unterdorf       NaN        NaN
# 3  Glattbrugg, Frohbühlstrasse       NaN        NaN
# 4         Bassersdorf, Bahnhof       NaN        NaN
# 6         Wetzikon ZH, Bahnhof       NaN        NaN

# %%
# here the we merge the city_df and df_indirectEffect
merged_df = pd.merge(left=df_indirectEffect_no_duplication, right=city_df)
merged_df.head()
# Out:
#    iteration    personId     time   OutTime triggerType  currentStopName  \
# 0          0  1557445300  57852.0   16:4:12         T-2  Zürich Oerlikon
# 1          0  1248398200  58667.0  16:17:47         T-2  Zürich Oerlikon
# 2          0  1060282700  60012.0  16:40:12         T-2  Zürich Oerlikon
# 3          0  1086246801  60012.0  16:40:12         T-2  Zürich Oerlikon
# 4          0   914693600  60192.0  16:43:12         T-2  Zürich Oerlikon
#
#                transitLine transitRoute      vehicle      nextStopName  \
# 0   SBB_S6_8503105-8503504    18622_003  S_SBB_04321    Zürich Seebach
# 1  SBB_S24_8502204-8506000    20420_001  S_SBB_05050  Zürich Flughafen
# 2   SBB_S9_8503125-8503424    18920_002  S_SBB_04557        Glattbrugg
# 3   SBB_S9_8503125-8503424    18920_002  S_SBB_04557        Glattbrugg
# 4  SBB_S21_8503000-8503526    20162_008  S_SBB_04998  Zürich Affoltern
#
#    passengersSize  passengerCapacit     _merge   latitude  longitude
# 0               0                30  left_only  47.412036   8.544317
# 1               0                30  left_only  47.412036   8.544317
# 2               0                30  left_only  47.412036   8.544317
# 3               0                30  left_only  47.412036   8.544317
# 4               0                30  left_only  47.412036   8.544317

# %%
# save the "indirectEffect" into a excel file
merged_df.to_excel("indirectEffect_visual.xlsx")

# %% [markdown]
# ############### Data Analysis #######################

# %%
merged_df["category"] = "Red"
merged_df1 = merged_df[["currentStopName", "category",  "latitude","longitude","personId", "triggerType"]]
merged_df1.head()
# Out:
#    currentStopName category   latitude  longitude    personId triggerType
# 0  Zürich Oerlikon      Red  47.412036   8.544317  1557445300         T-2
# 1  Zürich Oerlikon      Red  47.412036   8.544317  1248398200         T-2
# 2  Zürich Oerlikon      Red  47.412036   8.544317  1060282700         T-2
# 3  Zürich Oerlikon      Red  47.412036   8.544317  1086246801         T-2
# 4  Zürich Oerlikon      Red  47.412036   8.544317   914693600         T-2

# %%
personId_df = merged_df1.groupby(["personId", "currentStopName","latitude","longitude", "triggerType"]).count()
personId_df.head(10)
# Out:
#                                                                         category
# personId  currentStopName              latitude  longitude triggerType
# 759147200 Brüttisellen, Ob. Wangenstr. 47.424258 8.630773  T-2                 1
# 760196600 Zürich Oerlikon              47.412036 8.544317  T-2                 1
# 775420400 Zürich HB                    47.378101 8.539364  T-2                 1
# 777639500 Zürich HB                    47.378101 8.539364  T-2                 1
# 797580500 Opfikon, Austrasse           47.432267 8.577998  T-2                 1
#           Zürich Hardbrücke, Bahnhof   47.385161 8.517393  T-2                 1
# 807239400 Niederglatt ZH, Nöschikon    47.495077 8.492097  T-2                 1
# 811642600 Zürich Oerlikon              47.412036 8.544317  T-2                 1
# 822365800 Zürich Oerlikon              47.412036 8.544317  T-2                 1
# 828805500 Opfikon, Austrasse           47.432267 8.577998  T-2                 2

# %%
personId_df.to_excel("indreictEffect_based_number_of_personId.xlsx")

# %%
## based on the stops
StopName_df = merged_df1.groupby(["currentStopName","latitude","longitude", "triggerType", "category"]).count()
StopName_df.head(50)
# Out:
#                                                                          personId
# currentStopName                latitude  longitude triggerType category
# Bachenbülach, alte Post        47.505065 8.546070  T-2         Red              3
# Bergdietikon, Dünni            47.389840 8.386526  T-2         Red              1
# Brüttisellen, Ob. Wangenstr.   47.424258 8.630773  T-2         Red              1
# Glattbrugg, Bahnhof            47.432631 8.564789  T-2         Red              1
# Glattbrugg, Lättenwiesen       47.432631 8.564789  T-2         Red              1
# Höri, Schulhaus                47.508503 8.506701  T-2         Red              1
# Küsnacht ZH, Bühlstrasse       47.319365 8.610749  T-2         Red              1
# Niederglatt ZH, Nöschikon      47.495077 8.492097  T-2         Red              1
# Niederhasli, Hofstetterstrasse 47.481607 8.492832  T-2         Red              1
# Opfikon, Austrasse             47.432267 8.577998  T-2         Red              3
# Regensdorf, Zentrum            47.431670 8.468694  T-2         Red              5
# Wallisellen, Bahnhof           47.416620 8.591999  T-2         Red              6
# Wallisellen, Belair            47.413459 8.584331  T-2         Red              3
# Winterthur, Hauptbahnhof       47.500300 8.724242  T-2         Red              1
# Zürich Flughafen, Fracht       47.449974 8.564134  T-2         Red              1
# Zürich Flughafen, Werft        47.449974 8.564134  T-2         Red              1
# Zürich HB                      47.378101 8.539364  T-2         Red             13
# Zürich Hardbrücke, Bahnhof     47.385161 8.517393  T-2         Red              8
# Zürich Oerlikon                47.412036 8.544317  T-2         Red             42
# Zürich Oerlikon, Bahnhof Ost   47.412036 8.544317  T-2         Red              1
# Zürich, Bahnhofquai/HB         47.377716 8.541794  T-2         Red              1
# Zürich, Chaletweg              47.423118 8.620314  T-2         Red              1
# Zürich, Ettenfeld              47.372394 8.542333  T-2         Red              1
# Zürich, Felsenrainstrasse      47.418599 8.541472  T-2         Red              1
# Zürich, Grünwald               47.578732 8.680598  T-2         Red              6
# Zürich, Im Ebnet               47.287868 8.557619  T-2         Red              4
# Zürich, Meierhofplatz          47.372394 8.542333  T-2         Red              1
# Zürich, Milchbuck              47.395173 8.540382  T-2         Red              1
# Zürich, Mötteliweg             47.372394 8.542333  T-2         Red              1
# Zürich, Radiostudio            47.402225 8.535251  T-2         Red             12
# Zürich, Schiffbau              47.388254 8.520230  T-2         Red              7
# Zürich, Schmiede Wiedikon      47.369926 8.519777  T-2         Red              1
# Zürich, Seebacherplatz         47.419240 8.547786  T-2         Red              3
# Zürich, Stampfenbachplatz      47.372394 8.542333  T-2         Red              1

# %%
StopName_df.to_excel("only_T2_indirectEffect_basedon_Station.xlsx")

# %% [markdown]
# ### The End
